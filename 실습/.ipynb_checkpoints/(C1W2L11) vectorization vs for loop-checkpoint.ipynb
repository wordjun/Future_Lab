# %% [markdown]
# # vectorization vs for loop

# %%
import numpy as np

# %%
a = np.random.rand(1000000)
b = np.random.rand(1000000)

# %% [markdown]
# ### for loop

# %%
# %%timeit
c=0
for i in range(len(a)):
    c += a[i]*b[i]
# Out:
# 459 ms ± 12.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### vectorization

# %%
# %%timeit
np.dot(a,b)
# Out:
# 703 µs ± 19.4 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
